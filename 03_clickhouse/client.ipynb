# %%
import clickhouse_connect 
import pandas as pd

client = clickhouse_connect.get_client(host='your-ip', port=8123, username='admin', password='password')  
query_result = client.query('SELECT * FROM iot_db.datamicdemo1') 
df = pd.DataFrame(query_result.result_rows)
print(df.head(5))
